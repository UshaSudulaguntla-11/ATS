# %% [markdown]
# <a href="https://colab.research.google.com/github/UshaSudulaguntla-11/ATS/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file=pd.read_csv("/content/simplelinearregression.csv")

# %%
file
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(file["Age"],file["Premium"])

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(file["Age"],file["Premium"])  To solve this use extra squarebrackets or pandas dataframe(since,we need to send iput as matrix for fit)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1648569784.py in <cell line: 0>()
# ----> 1 model.fit(file["Age"],file["Premium"])
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...

# %%
model.fit(file[["Age"]],file[["Premium"]])
# Out:
# LinearRegression()

# %%
model.predict([[19]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[12171.23287671]])

# %%
import pandas as pd

# %%
file=pd.read_csv("/content/multiple_linear_regression_dataset.csv")

# %%
file
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(file["age"],file["experience"],file["income"])

# %%
model.fit(file[["age","experience"]],file[["income"]])
# Out:
# LinearRegression()

# %%
model.predict([[47,9]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[46061.14587475]])

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
file=pd.read_csv("/content/simplelinearregression.csv")

# %%
x=file[["Age"]]
y=file["Premium"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[25]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19355.40540541])

# %%
model.predict(x_test)
# Out:
# array([11551.35135135, 17125.67567568])

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([11551.35135135, 17125.67567568])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1585567.0197224275
